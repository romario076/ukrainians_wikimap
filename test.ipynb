# %%
import re
import json
import time
import numpy as np
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
#from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize
from itertools import chain
import pydeck as pdk
from bs4 import BeautifulSoup

from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

import warnings
warnings.filterwarnings(action='ignore')

# %%
from IPython.display import display, HTML
display(HTML("<style>:root { --jp-notebook-max-width: 90% !important; }</style>"))
# Out:
# <style>:root { --jp-notebook-max-width: 90% !important; }</style>

# %%
#df = pd.read_csv("wiki_data_ukr_all.csv")
df = pd.read_csv("data_extractor/ukrainian_history_data_batched.csv")
df.shape
# Out:
# (87678, 24)

# %%
df.head(2)
# Out:
#            PersonName InstanceOf InstanceOfIDs       BirthPlace  \
# 0      Ігор Рюрикович     людина            Q5              NaN
# 1  Анна Порфірогенета     людина            Q5  Константинополь
#
#               BirthDate                Coordinates   DeathPlace  \
# 0  0878-00-00T00:00:00Z                        NaN  Іскоростень
# 1  0963-03-13T00:00:00Z  Point(28.976018 41.01224)         Київ
#
#               Coordinates_death             DeathDate  \
# 0  Point(28.6417552 50.9491068)  0945-00-00T00:00:00Z
# 1  Point(30.523611111111 50.45)  1011-01-01T00:00:00Z
#
#                                        WikipediaURL  ... Field  \
# 0      https://uk.wikipedia.org/wiki/Ігор_Рюрикович  ...   NaN
# 1  https://uk.wikipedia.org/wiki/Анна_Порфірогенета  ...   NaN
#
#                                             Position             Ethnicity  \
# 0  Великий князь Київський, Великий князь Новгоро...  Detected by metadata
# ...

# %%
### Fix Bogdan Khmelnytsky
df.loc[df['PersonName'] == 'Богдан Хмельницький', 'BirthPlace'] = "Суботів"
df.loc[df['PersonName'] == 'Богдан Хмельницький', 'Coordinates'] = "Point(32.549 49.095)"
df.loc[df['PersonName'] == 'Богдан Хмельницький', 'BirthDate'] = "27-12-1595"

# %%
df = df[~df.PersonName.str.contains("Мауру Родрігіш")]

# %%
df = df[~df.PersonName.str.contains("Аріельсон Сампайо Гальвао")]

# %%
df.to_csv("data_extractor/ukrainian_history_data_batched.csv", index=False)
